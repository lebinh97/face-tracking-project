# %%
import subprocess
import time

# Paths to your scripts
LOGGING_SCRIPT = "/home/bngl1/projects/cs5939/Cloud Monitoring Service/cloud_logging.py"
MONITORING_SCRIPT = "/home/bngl1/projects/cs5939/Cloud Monitoring Service/cloud_monitoring.py"

# Start both processes
p1 = subprocess.Popen(["python3", LOGGING_SCRIPT])
p2 = subprocess.Popen(["python3", MONITORING_SCRIPT])

print("🚀 Running cloud_logging.py and cloud_monitoring.py ...")
print("Press CTRL + C to stop both.")

try:
    # Keep alive
    while True:
        time.sleep(1)

except KeyboardInterrupt:
    print("\n🛑 Stopping...")
    p1.terminate()
    p2.terminate()
    print("✔️ Both stopped.")
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://0.0.0.0:7999/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Error: Expecting property name enclosed in double quotes: line 2470 column 7 (char 81997)
# Error: Expecting ',' delimiter: line 5178 column 37 (char 172162)

# %%
# !pip install dash-bootstrap-components
# Out:
# Collecting dash-bootstrap-components
#   Using cached dash_bootstrap_components-2.0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: dash>=3.0.4 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from dash-bootstrap-components) (3.3.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from dash>=3.0.4->dash-bootstrap-components) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from dash>=3.0.4->dash-bootstrap-components) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from dash>=3.0.4->dash-bootstrap-components) (6.4.0)
# Requirement already satisfied: importlib-metadata in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from dash>=3.0.4->dash-bootstrap-components) (8.7.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from dash>=3.0.4->dash-bootstrap-components) (4.15.0)
# Requirement already satisfied: requests in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from dash>=3.0.4->dash-bootstrap-components) (2.32.5)
# Requirement already satisfied: retrying in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from dash>=3.0.4->dash-bootstrap-components) (1.4.2)
# Requirement already satisfied: nest-asyncio in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from dash>=3.0.4->dash-bootstrap-components) (1.6.0)
# Requirement already satisfied: setuptools in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from dash>=3.0.4->dash-bootstrap-components) (53.0.0)
# Requirement already satisfied: blinker>=1.9.0 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (8.1.8)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (3.0.3)
# Requirement already satisfied: zipp>=3.20 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from importlib-metadata->dash>=3.0.4->dash-bootstrap-components) (3.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from plotly>=5.0.0->dash>=3.0.4->dash-bootstrap-components) (2.11.0)
# Requirement already satisfied: packaging in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from plotly>=5.0.0->dash>=3.0.4->dash-bootstrap-components) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bngl1/venv_cs5939/lib/python3.9/site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (2025.10.5)
# Using cached dash_bootstrap_components-2.0.4-py3-none-any.whl (204 kB)
# Installing collected packages: dash-bootstrap-components
# Successfully installed dash-bootstrap-components-2.0.4
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import subprocess
import time

# Paths to your scripts
LOGGING_SCRIPT = "/home/bngl1/projects/cs5939/Cloud Monitoring Service/cloud_logging.py"
MONITORING_SCRIPT = "/home/bngl1/projects/cs5939/Cloud Monitoring Service/cloud_monitoring.py"

# Start both processes
p1 = subprocess.Popen(["python3", LOGGING_SCRIPT])
p2 = subprocess.Popen(["python3", MONITORING_SCRIPT])

print("🚀 Running cloud_logging.py and cloud_monitoring.py ...")
print("Press CTRL + C to stop both.")

try:
    # Keep alive
    while True:
        time.sleep(1)

except KeyboardInterrupt:
    print("\n🛑 Stopping...")
    p1.terminate()
    p2.terminate()
    print("✔️ Both stopped.")
# Out:
# 🚀 Running cloud_logging.py and cloud_monitoring.py ...
# Press CTRL + C to stop both.
# Dash is running on http://0.0.0.0:7999/
#
#  * Serving Flask app 'cloud_monitoring'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:7999
#  * Running on http://10.0.0.1:7999
# Press CTRL+C to quit
# 127.0.0.1 - - [22/Nov/2025 11:07:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:19] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:19] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:19] "GET /_favicon.ico?v=3.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:19] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Nov/2025 11:07:19] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Nov/2025 11:07:19] "GET /_dash-component-suites/plotly/package_data/plotly.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Nov/2025 11:07:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:07:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:08:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:08:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:08:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:08:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Nov/2025 11:08:09] "POST /_dash-update-component HTTP/1.1" 200 -
